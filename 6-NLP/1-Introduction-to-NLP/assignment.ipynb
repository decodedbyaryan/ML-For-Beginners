# %% [markdown]
# # Assignment
#
# ## Chosen chatbot and where was it found
# The chosen chatbot is **Text Support** by text.com. It was found on **livechat.com**.
#
# ## The tried test and the results
# **Test**- It was a simple test where the chatbot was asked some out of context questions to see if it could respond accordingly.
#
# **Question**- 1 + 1 =
# **Response**- didn't solve the maths problem but rather gave a generic answer, asking specifically to ask something about its company or service
#
# **Question**- 000
# **Response**- the same answer as above but rephrased
#
# **Question**- lemon
# **Response**- the same answer, again rephrased
#
# **Question**- knock knock
# **Response**- again the same rephrased text
#
# **And the cycle repeated a couple of more times**
#
# ## Why it got confused?
# Because it wasn't trained to do anything else except answer some basic questions about its own company and service, atmost it would ask for contact details at the end of a successful conversation which I doubt it can have considering it didn't do that for me which generally happens while you are talking to any chatbot so that the company can reach back to the clients or catch leads. Most likely the answer to this is that this chatbot was built only to answer or put out what it has already been given and just rephrase it.
#
# ## What this tells us about how the bot is built
# Hmm, I think it tells us that this bot is just an advanced brother of ELIZA (the first chatbot in history), that just gives out pre-fed responses and can work in only certain situation which I am not too sure would be.
#
# # Final Conclusion
# This assignment taught me what I have to look after when I will be making my own chatbot or something similar in the future. We all should take inspiration and have pride that the first chatbot was created in the 1960's but at the same time seeing how advanced everything is getting, make something accordingly to honor that first spark.
